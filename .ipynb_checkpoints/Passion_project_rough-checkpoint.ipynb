# %%
import pandas as pd

# %%
import glob

# %%
import re

# %%
path =r'/home/farhaan/working_projects/fatalitydata'
allFiles = glob.glob(path + "/*.csv")
regex = re.compile('(?<=/)[\w]+(?=\.csv)')
df_name_list = []
for file_path in allFiles:
    print(file_path)
    file_name = re.findall(regex,file_path)[0]
    df_name_list.append("df_"+file_name)
    exec("df_"+file_name+" = pd.read_csv(file_path,index_col=None, header=0,error_bad_lines=False)")
# Out:
# /home/farhaan/working_projects/fatalitydata/drimpair.csv
# /home/farhaan/working_projects/fatalitydata/cevent.csv
# /home/farhaan/working_projects/fatalitydata/damage.csv
# /home/farhaan/working_projects/fatalitydata/vsoe.csv
# /home/farhaan/working_projects/fatalitydata/miper.csv
# /home/farhaan/working_projects/fatalitydata/accident.csv
# /home/farhaan/working_projects/fatalitydata/nmcrash.csv
# /home/farhaan/working_projects/fatalitydata/nmimpair.csv
# /home/farhaan/working_projects/fatalitydata/person.csv
# /home/farhaan/working_projects/fatalitydata/vindecode.csv
# /home/farhaan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2821: DtypeWarning: Columns (13,23,49,50,94) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# /home/farhaan/working_projects/fatalitydata/violatn.csv
# /home/farhaan/working_projects/fatalitydata/parkwork.csv
# /home/farhaan/working_projects/fatalitydata/distract.csv
# ...

# %%
df_name_list
# Out:
# ['df_drimpair',
#  'df_cevent',
#  'df_damage',
#  'df_vsoe',
#  'df_miper',
#  'df_accident',
#  'df_nmcrash',
#  'df_nmimpair',
#  'df_person',
#  'df_vindecode',
#  'df_violatn',
#  'df_parkwork',
#  'df_distract',
#  'df_maneuver',
#  'df_safetyeq',
#  'df_miacc',
#  'df_pbtype',
#  'df_midrvacc',
#  'df_factor',
#  'df_vevent',
#  'df_vision',
#  'df_nmprior',
#  'df_vehicle']

# %%
df_vehicle
# Out:
#       STATE  ST_CASE  VEH_NO  PER_NO  MPR_ACT
# 0         1    10008       0       1        3
# 1         1    10031       0       1        3
# 2         1    10040       0       1        8
# 3         1    10042       0       1        3
# 4         1    10050       0       1        5
# 5         1    10055       0       1        5
# 6         1    10059       0       1        5
# 7         1    10064       0       1        5
# 8         1    10069       0       1        3
# 9         1    10072       0       1        3
# 10        1    10073       0       1        3
# 11        1    10076       0       1        8
# 12        1    10077       0       1        5
# 13        1    10088       0       1        3
# 14        1    10090       0       1        8
# 15        1    10098       0       1        3
# 16        1    10113       0       1        3
# 17        1    10117       0       1        8
# 18        1    10124       0       1        3
# ...

# %%
read/home/farhaan/working_projects/fatalitydata/
